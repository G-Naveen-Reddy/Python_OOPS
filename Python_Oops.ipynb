# %% [markdown]
# 1. What is Object-Oriented Programming (OOP) ?
# - Object-Oriented Programming (OOP) is a programming approach where everything is organized into objects, which are real-world-like entities that contain both data (called attributes) and functions (called methods) that work on that data.
#
#  Key Concepts:
#
#  Class – A blueprint for creating objects.
#
#  Object – An instance of a class.
#
#  Encapsulation – Keeping data and methods together in a single unit (object).
#
#  Inheritance – One class can inherit features from another.
#
#  Polymorphism – Same function name can work differently for different classes.
#
#  Abstraction – Hiding complex details and showing only the essentials.
#
#  Example:
#  If you create a class Car, it can have attributes like color and speed, and methods like drive() and brake().
#
#  You can then create multiple Car objects with different values and use their functions.
#
#  Let me know if you want this in a simpler form or in your native language too!

# %% [markdown]
# 2. What is a class in OOP?
#
#  A class in OOP is a template or blueprint used to create objects.
#
#  It defines the properties (like name, color, size) and behaviors (like move, run, stop) that the object will have.

# %% [markdown]
# 3. What is an object in OOP ?
# - An object in OOP is an instance of a class.
#
#  It represents a real-world entity that has specific properties and behaviors defined by its class.

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation ?
# - Abstraction is about hiding unnecessary details and showing only the important parts.
#
#  → Focuses on what an object does.
#
#  Encapsulation is about hiding the internal data and protecting it from outside access.
#
#  → Focuses on how the object does it, keeping everything together in one unit.

# %% [markdown]
# 5. What are dunder methods in Python ?
# - Dunder methods in Python are special methods that have double underscores at the beginning and end of their names (like __init__, __str__, __len__).
#
#  They are also called magic methods and are used to define how objects behave with built-in functions and operators.
#
#  Examples:
#
#  __init__ → Initializes a new object
#
#  __str__ → Returns a string representation
#
#  __add__ → Defines behavior for + operator

# %% [markdown]
# 6. Explain the concept of inheritance in OOP ?
# - Inheritance in OOP is the concept where one class (child) can use the properties and methods of another class (parent).
#
#  It helps in reusing code and creating a relationship between classes.
#
#  Simple Example (without code):
#
#  If you have a Parent class called Animal with features like eat and sleep, a Child class like Dog can inherit those features without writing them again.
#
#  The child can also have its own extra features, like bark.
#
#  In short: Inheritance means a class can take features from another class, promoting code reuse and organization.

# %% [markdown]
# 7. What is polymorphism in OOP ?
# - Polymorphism in OOP means the same function or method can behave differently depending on the object using it.
#
#  Simple Meaning:
#
#  "One name, many forms."
#
#  Example (without code):
#
#  If you have a method called speak():
#
#  For a Dog object, speak() might mean barking.
#
#  For a Cat object, speak() might mean meowing.
#
#  In short:
#
#   Polymorphism allows different objects to use the same method name, but with different behaviors.

# %% [markdown]
# 8. How is encapsulation achieved in Python ?
# - Encapsulation in Python is achieved by hiding data using private variables and controlling access through methods.
#
#  How it's done:
#
#  By using underscores before variable names:
#
#  _name → protected (convention)
#
#  __name → private (name mangling)
#
#  By using getter and setter methods to access or update private data safely.

# %% [markdown]
# 9. What is a constructor in Python ?
# - A constructor in Python is a special method used to automatically initialize an object when it is created.
#
#  In Python, the constructor method is called __init__.
#
#  In short: A constructor sets up the initial state (like values of variables) of an object when it is created from a class.

# %% [markdown]
# 10. What are class and static methods in Python ?
# - In Python:
#
#  Class Method:
#
#  Defined using @classmethod decorator.
#
#  Takes the class itself as the first argument (cls).
#
#  Can access or modify class-level variables.
#
#  Used when the method needs to operate on the class, not just an instance.
#
#  Static Method:
#
#  Defined using @staticmethod decorator.
#
#  Doesn’t take self or cls as the first argument.
#
#  It’s just like a regular function but belongs to the class’s namespace.
#
#  Doesn't operate on instance or class variables, but can be used to group functions logically inside the class.

# %% [markdown]
# 11. What is method overloading in Python ?
# - Method overloading in Python isn't directly supported, unlike some other languages like Java. However, Python allows you to mimic overloading using default arguments or variable-length arguments.

# %% [markdown]
# 12. What is method overriding in OOP ?
# - Method overriding in OOP occurs when a child class provides a new implementation of a method that is already defined in its parent class.
#
#  The child class overrides the parent class method to give it a different behavior while keeping the same method signature (name and parameters).

# %% [markdown]
# 13. What is a property decorator in Python ?
# - The @property decorator in Python is used to turn a method into a read-only property. It allows you to access a method like an attribute, without explicitly calling it like a function.

# %% [markdown]
# 14. Why is polymorphism important in OOP ?
# - Polymorphism is important in OOP because it promotes flexibility and extensibility by allowing objects of different classes to be treated as instances of the same class through a common interface.

# %% [markdown]
# 15. What is an abstract class in Python ?
# - An abstract class in Python is a class that cannot be instantiated directly. It is meant to be a blueprint for other classes. Abstract classes are used to define methods that must be implemented by their subclasses, ensuring that the subclasses provide specific functionality.

# %% [markdown]
# 16. What are the advantages of OOP ?
# - he advantages of Object-Oriented Programming (OOP) are:
#
#  Modularity: Code is organized into classes and objects, which makes it easier to manage and scale. Each object is self-contained and can be worked on independently.
#
#  Reusability: Through inheritance, you can reuse code from existing classes, reducing duplication and making code more efficient.
#
#  Flexibility and Extensibility: With polymorphism, new functionality can be added without modifying existing code, making it easier to extend and modify systems as requirements change.
#
#  Encapsulation: Data hiding is possible, so the internal workings of an object are hidden from outside code. This helps in protecting the integrity of the data and allows for more control over how the data is accessed or modified.
#
#  Maintainability: OOP promotes clearer structure and organization of code. This makes it easier to maintain and update as new requirements arise.
#
#  Abstraction: OOP allows focusing on high-level functionality
#  while hiding unnecessary implementation details, making the system easier to understand and use.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable ?
# - Class Variable:
#
#  Belongs to the class itself, not to any specific object.
#
#  Shared across all instances (objects) of the class.
#
#  If changed, it reflects in all objects of the class.
#
#  Instance Variable:
#
#  Belongs to a specific instance (object) of the class.
#
#  Each object has its own copy of the instance variable.
#
#  Changes in one object’s instance variable do not affect other objects.

# %% [markdown]
# 18. What is multiple inheritance in Python ?
# - Multiple inheritance in Python refers to a feature where a class can inherit attributes and methods from more than one parent class. This allows a child class to combine functionalities from multiple parent classes

# %% [markdown]
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?
# - The __str__ and __repr__ methods in Python serve to provide string representations of objects, but they are used in different contexts:
#
#  __str__ Method:
#
#  The __str__ method is used to define a user-friendly string representation of an object.
#
#  It's intended to be readable and provide a simple description of the object for end users.
#
#  It's used when you call print() or str() on an object.
#
#  __repr__ Method:
#
#  The __repr__ method is used to define a formal string representation of an object.
#
#  It is intended to provide a detailed or unambiguous description of the object, often one that could be used to recreate the object (i.e., the output should be valid Python code if possible).
#
#  It’s used when you call repr() on an object or in the interactive interpreter.

# %% [markdown]
# 20. What is the significance of the ‘super()’ function in Python ?
# - The super() function in Python is used to call methods from a parent class in a child class, allowing the child class to access or override methods from the parent class.
#
#  Significance:
#
#  Access Parent Class Methods: It allows you to call a method from the parent class without explicitly naming the parent class. This is especially useful in multiple inheritance.
#
#  Avoid Redundant Code: Using super() helps in calling the parent class's method and extending or modifying it in the child class, reducing code duplication.
#
#  Method Resolution Order (MRO): In cases of multiple inheritance, super() helps Python decide the order in which methods should be called, following the MRO.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python ?
# - The __del__ method in Python is a special method called the destructor. It is automatically invoked when an object is about to be destroyed or garbage collected.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python ?
# - The difference between @staticmethod and @classmethod in Python lies in how they interact with the class and its instances:
#
#  @staticmethod:
#
#  A static method doesn't take any special first argument (self or cls).
#
#  It behaves like a regular function, but it belongs to the class's namespace.
#
#  It can't access or modify class-level or instance-level variables directly.
#
#  Used when the method doesn't need access to instance-specific or class-specific data but logically belongs to the class.
#
#  @classmethod:
#
#  A class method takes the class itself (cls) as the first argument.
#
#  It can access and modify class-level variables.
#
#  It’s used when a method needs to operate on class-level data or needs to create instances of the class.

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance ?
# - In Python, polymorphism works with inheritance by allowing objects of different classes to be treated as objects of a common base class. This allows a child class to override a method from the parent class, so the method behaves differently depending on the object type. Despite the difference in behavior, the same method name can be used for all the objects.

# %% [markdown]
# 24. What is method chaining in Python OOP ?
# - Method chaining in Python OOP refers to the practice of calling multiple methods on the same object in a single line, where each method returns the object itself or another object that allows for further method calls.
#
#  This technique relies on each method returning the object (or itself) after performing its operation, so you can continue to call subsequent methods on the same object.

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?
# - The __call__ method in Python is a special method that allows an instance of a class to be called like a function. This means that you can make an object behave like a function, enabling it to be invoked with parentheses, as if it were a callable object.
#
#  Purpose:
#
#  The __call__ method allows you to define custom behavior for objects when they are called.
#
#  It is useful for creating objects that can be used as functions or for scenarios where the object needs to "act" like a function, such as in functional programming paradigms.

# %%
'''
1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
'''
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

dog = Dog()
dog.speak()  # Output: Bark!
# Out:
# Bark!

# %%
'''Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.'''
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)

print(circle.area())  # Output: 78.5
print(rectangle.area())  # Output: 24
# Out:
# 78.5
# 24

# %%
'''
3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
'''
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, model):
        super().__init__(type)
        self.model = model

class ElectricCar(Car):
    def __init__(self, type, model, battery):
        super().__init__(type, model)
        self.battery = battery

electric_car = ElectricCar("Electric", "Tesla", "100kWh")
print(electric_car.type)  # Output: Electric
print(electric_car.model)  # Output: Tesla
print(electric_car.battery)  # Output: 100kWh
# Out:
# Electric
# Tesla
# 100kWh

# %%
'''
4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
'''
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow is flying")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

bird = Bird()
sparrow = Sparrow()
penguin = Penguin()

bird.fly()  # Output: Bird is flying
sparrow.fly()  # Output: Sparrow is flying
penguin.fly()  # Output: Penguin cannot fly
# Out:
# Bird is flying
# Sparrow is flying
# Penguin cannot fly

# %%
'''
5.Write a program to demonstrate encapsulation by creating a class BankAccount
with private attributes balance and methods to deposit, withdraw, and check balance.
'''
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance  # Private attribute

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if self.__balance >= amount:
            self.__balance -= amount
        else:
            print("Insufficient funds")

    def check_balance(self):
        return self.__balance

account = BankAccount(1000)
account.deposit(500)
print(account.check_balance())  # Output: 1500
account.withdraw(200)
print(account.check_balance())  # Output: 1300
# Out:
# 1500
# 1300

# %%
'''
6.Demonstrate runtime polymorphism using a method play() in a base class Instrument.
Derive classes Guitar and Piano that implement their own version of play().
'''
class Instrument:
    def play(self):
        pass

class Guitar(Instrument):
    def play(self):
        print("Playing guitar")

class Piano(Instrument):
    def play(self):
        print("Playing piano")

instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Playing guitar
# Playing piano

# %%
'''
7.Create a class MathOperations with a class method add_numbers() to add two
numbers and a static method subtract_numbers() to subtract two numbers
'''
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5, 3))  # Output: 8
print(MathOperations.subtract_numbers(5, 3))  # Output: 2
# Out:
# 8
# 2

# %%
'''
8.Implement a class Person with a class method to count the total number of persons created.
'''
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def get_person_count(cls):
        return cls.count

person1 = Person("Alice")
person2 = Person("Bob")
print(Person.get_person_count())  # Output: 2
# Out:
# 2

# %%
'''
9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
'''
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

fraction = Fraction(3, 4)
print(fraction)  # Output: 3/4
# Out:
# 3/4

# %%
'''
10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
'''
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(1, 2)
v2 = Vector(3, 4)
v3 = v1 + v2  # Calls the __add__ method

print(v3)  # Output: (4, 6)
# Out:
# (4, 6)

# %%
'''
11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
'''
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person = Person("John", 30)
person.greet()  # Output: Hello, my name is John and I am 30 years old.
# Out:
# Hello, my name is John and I am 30 years old.

# %%
'''
12.Implement a class Student with attributes name and grades.
Create a method average_grade() to compute the average of the grades.
'''
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

student = Student("Alice", [90, 85, 88])
print(student.average_grade())  # Output: 87.6667
# Out:
# 87.66666666666667

# %%
'''
13.Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
'''
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

rect = Rectangle()
rect.set_dimensions(4, 6)
print(rect.area())  # Output: 24
# Out:
# 24

# %%
'''
14.Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
'''
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

manager = Manager(160, 50, 500)
print(manager.calculate_salary())  # Output: 8500
# Out:
# 8500

# %%
'''
15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the p
'''
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

product = Product("Laptop", 1000, 5)
print(product.total_price())  # Output: 5000
# Out:
# 5000

# %%
'''
16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
'''
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

cow = Cow()
sheep = Sheep()

cow.sound()  # Output: Moo
sheep.sound()  # Output: Baa
# Out:
# Moo
# Baa

# %%
'''
17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
'''
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"

book = Book("1984", "George Orwell", 1949)
print(book.get_book_info())  # Output: Title: 1984, Author: George Orwell, Year: 1949
# Out:
# Title: 1984, Author: George Orwell, Year: 1949

# %%
'''
18.Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
'''
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

mansion = Mansion("123 Luxury St.", 1000000, 10)
print(mansion.address)  # Output: 123 Luxury St.
print(mansion.price)  # Output: 1000000
print(mansion.number_of_rooms)  # Output: 10
# Out:
# 123 Luxury St.
# 1000000
# 10
